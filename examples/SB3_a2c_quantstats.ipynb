# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gymnasium as gym
import gym_anytrading
from gym_anytrading.envs import Actions

from stable_baselines3 import A2C

import quantstats as qs

# %% [markdown]
# ### Create Env

# %%
df = gym_anytrading.datasets.STOCKS_GOOGL.copy()

window_size = 10
start_index = window_size
end_index = len(df)

env = gym.make(
    'stocks-v0',
    df=df,
    window_size=window_size,
    frame_bound=(start_index, end_index)
)

print("observation_space:", env.observation_space)
# Out:
# observation_space: Box(-10000000000.0, 10000000000.0, (10, 2), float32)

# %% [markdown]
# ### Train Env

# %%
env.reset(seed=2023)
model = A2C('MlpPolicy', env, verbose=0)
model.learn(total_timesteps=1_000)

# %% [markdown]
# ### Test Env

# %%
action_stats = {Actions.Sell: 0, Actions.Buy: 0}

observation, info = env.reset(seed=2023)

while True:
    # action = env.action_space.sample()
    action, _states = model.predict(observation)

    action_stats[Actions(action)] += 1
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        break

env.close()

print("action_stats:", action_stats)
print("info:", info)
# Out:
# action_stats: {<Actions.Sell: 0>: 1351, <Actions.Buy: 1>: 973}
# info: {'total_reward': 625.4919891357422, 'total_profit': 0.00048684219339681156, 'position': <Positions.Short: 0>}

# %% [markdown]
# ### Plot Results

# %%
plt.figure(figsize=(16, 6))
env.unwrapped.render_all()
plt.show()

# %% [markdown]
# ### Analysis Using `quantstats`

# %%
qs.extend_pandas()

net_worth = pd.Series(env.unwrapped.history['total_profit'], index=df.index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
qs.reports.html(returns, output='SB3_a2c_quantstats.html')
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2009-06-10
# End Period                 2018-08-29
# Risk-Free Rate             0.0%
# Time in Market             26.0%
#
# Cumulative Return          -99.95%
# CAGR﹪                     -43.5%
#
# Sharpe                     -4.77
# Prob. Sharpe Ratio         0.0%
# Smart Sharpe               -4.36
# Sortino                    -4.91
# Smart Sortino              -4.49
# Sortino/√2                 -3.47
# Smart Sortino/√2           -3.17
# Omega                      0.16
#
# Max Drawdown               -99.95%
# Longest DD Days            3362
# Volatility (ann.)          16.99%
# Calmar                     -0.44
# Skew                       -1.94
# Kurtosis                   14.57
#
# Expected Daily %           -0.33%
# Expected Monthly %         -6.64%
# Expected Yearly %          -53.36%
# Kelly Criterion            -102.2%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.08%
# Expected Shortfall (cVaR)  -2.08%
#
# Max Consecutive Wins       1
# Max Consecutive Losses     1
# Gain/Pain Ratio            -0.84
# Gain/Pain (1M)             -0.99
#
# Payoff Ratio               0.67
# Profit Factor              0.16
# Common Sense Ratio         0.0
# CPC Index                  0.02
# Tail Ratio                 0.0
# Outlier Win Ratio          29.12
# Outlier Loss Ratio         2.37
#
# MTD                        -6.99%
# 3M                         -18.28%
# 6M                         -41.07%
# YTD                        -48.55%
# 1Y                         -55.88%
# 3Y (ann.)                  -45.82%
# 5Y (ann.)                  -45.19%
# 10Y (ann.)                 -43.5%
# All-time (ann.)            -43.5%
#
# Best Day                   9.05%
# Worst Day                  -11.43%
# Best Month                 5.22%
# Worst Month                -16.7%
# Best Year                  -38.39%
# Worst Year                 -65.26%
#
# Avg. Drawdown              -99.95%
# Avg. Drawdown Days         3362
# Recovery Factor            7.48
# Ulcer Index                0.89
# Serenity Index             -0.07
#
# Avg. Up Month              2.51%
# Avg. Down Month            -6.83%
# Win Days %                 19.15%
# Win Month %                2.7%
# Win Quarter %              0.0%
# Win Year %                 0.0%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2009-06-16  2018-08-22  2018-08-29  3362    -99.950257        -99.945944
# <h4>Strategy Visualization</h4>
